# %%
from pandas import read_csv

RAW_HOTEL_URL = "https://raw.githubusercontent.com/aaqibqadeer/Hotel-booking-demand/refs/heads/master/hotel_bookings.csv"

hotel_bookings = read_csv(RAW_HOTEL_URL)
hotel_bookings.to_csv("../data/raw/hotel_bookings.csv", index=False)
hotel_bookings.shape
# Out:
# (119390, 32)
